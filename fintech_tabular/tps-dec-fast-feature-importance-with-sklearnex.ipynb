# %% [markdown]
# <div style="background-color:rgba(0, 167, 255, 0.6);border-radius:5px;display:fill">
#     <h1><center>Tabular Playground Series - Dec 2021
# </div>

# %% [markdown]
# <center><a><img src="https://i.ibb.co/PWvpT9F/header.png" alt="header" border="0" width=800 height=400 class="center"></a>

# %% [markdown]
# For classical machine learning algorithms, we often use the most popular Python library, Scikit-learn. With Scikit-learn you can fit models and search for optimal parameters, but it sometimes works for hours. Speeding up this process is something anyone who uses Scikit-learn would be interested in.
#
# I want to show you how to use Scikit-learn library and get the results faster without changing the code. To do this, we will make use of another Python library, [**Intel® Extension for Scikit-learn***](https://github.com/intel/scikit-learn-intelex). It accelerates Scikit-learn and does not require you to change the code written for Scikit-learn.
#
# I will show you how to **speed up** your kernel without changing your code!

# %% [markdown]
# <div style="background-color:rgba(0, 167, 255, 0.6);border-radius:5px;display:fill">
#     <h1><center>Importing Libraries and Data</center></h1>
# </div>

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
from IPython.display import HTML
import warnings
warnings.filterwarnings("ignore")

import matplotlib.pyplot as plt

# %% [markdown]
# ### Reading Data

# %%
PATH_TRAIN      = '../input/tabular-playground-series-dec-2021/train.csv'
PATH_TEST       = '../input/tabular-playground-series-dec-2021/test.csv'
PATH_SUBMISSION = '../input/tabular-playground-series-dec-2021/sample_submission.csv'

# %%
train_data = pd.read_csv(PATH_TRAIN)
test_data  = pd.read_csv(PATH_TEST)
submission = pd.read_csv(PATH_SUBMISSION)

# %% [markdown]
# ### Reduce DataFrame memory usage
#
# Since data is quite big for Kaggle notebook instance RAM, we need to reduce memory usage by switching data types.

# %%
def reduce_memory_usage(df):
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != 'object':
            c_min = df[col].min()
            c_max = df[col].max()
            
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)
            
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    pass
        else:
            df[col] = df[col].astype('category')
    
    return df

# %%
train_data = reduce_memory_usage(train_data)
test_data  = reduce_memory_usage(test_data)

# %%
train_data = train_data.drop(['Id', 'Soil_Type7', 'Soil_Type15'], axis = 1)
test_data = test_data.drop(['Id', 'Soil_Type7', 'Soil_Type15'], axis = 1)

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000000 entries, 0 to 3999999
# Data columns (total 53 columns):
#  #   Column                              Dtype
# ---  ------                              -----
#  0   Elevation                           int16
#  1   Aspect                              int16
#  2   Slope                               int8
#  3   Horizontal_Distance_To_Hydrology    int16
#  4   Vertical_Distance_To_Hydrology      int16
#  5   Horizontal_Distance_To_Roadways     int16
#  6   Hillshade_9am                       int16
#  7   Hillshade_Noon                      int16
#  8   Hillshade_3pm                       int16
#  9   Horizontal_Distance_To_Fire_Points  int16
#  10  Wilderness_Area1                    int8
#  11  Wilderness_Area2                    int8
#  12  Wilderness_Area3                    int8
#  13  Wilderness_Area4                    int8
#  14  Soil_Type1                          int8
#  15  Soil_Type2                          int8
#  16  Soil_Type3                          int8
#  17  Soil_Type4                          int8
#  18  Soil_Type5                          int8
#  19  Soil_Type6                          int8
#  20  Soil_Type8                          int8
#  21  Soil_Type9                          int8
#  22  Soil_Type10                         int8
#  23  Soil_Type11                         int8
#  24  Soil_Type12                         int8
#  25  Soil_Type13                         int8
#  26  Soil_Type14                         int8
#  27  Soil_Type16                         int8
#  28  Soil_Type17                         int8
#  29  Soil_Type18                         int8
#  30  Soil_Type19                         int8
#  31  Soil_Type20                         int8
#  32  Soil_Type21                         int8
#  33  Soil_Type22                         int8
#  34  Soil_Type23                         int8
#  35  Soil_Type24                         int8
#  36  Soil_Type25                         int8
#  37  Soil_Type26                         int8
#  38  Soil_Type27                         int8
#  39  Soil_Type28                         int8
#  40  Soil_Type29                         int8
#  41  Soil_Type30                         int8
#  42  Soil_Type31                         int8
#  43  Soil_Type32                         int8
#  44  Soil_Type33                         int8
#  45  Soil_Type34                         int8
#  46  Soil_Type35                         int8
#  47  Soil_Type36                         int8
#  48  Soil_Type37                         int8
#  49  Soil_Type38                         int8
#  50  Soil_Type39                         int8
#  51  Soil_Type40                         int8
#  52  Cover_Type                          int8
# dtypes: int16(9), int8(44)
# memory usage: 236.5 MB

# %% [markdown]
# Collect garbage to reduce memory usage

# %%
import gc

gc.collect()
# Out:
# 96

# %% [markdown]
# ### Intel® Extension for Scikit-learn installation:

# %%
# !pip install scikit-learn-intelex -q --progress-bar off > /dev/null 2>&1

# %% [markdown]
# ### Accelerate Scikit-learn with two lines of code:

# %%
from sklearnex import patch_sklearn
patch_sklearn()
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %% [markdown]
# Setup logging to track accelerated cases:

# %%
import logging

logger = logging.getLogger()
fh     = logging.FileHandler('log.txt')

fh.setLevel(10)
logger.addHandler(fh)

# %% [markdown]
# <div style="background-color:rgba(0, 167, 255, 0.6);border-radius:5px;display:fill">
#     <h1><center>Feature importance</center></h1>
# </div>

# %% [markdown]
# One of the most basic questions we might ask of a model is: What features have the biggest impact on predictions?
#
# This concept is called feature importance.
#
# There are multiple ways to measure feature importance. In this kernel we consider permutation importance using library ELI5.

# %%
X, y = train_data.drop(['Cover_Type'], axis = 1), train_data['Cover_Type']

# %%
from sklearn.model_selection import train_test_split
from timeit import default_timer as timer

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size = 0.1, random_state = 42)

# %% [markdown]
# ### ELI5

# %% [markdown]
# ELI5 provides a way to compute feature importances for any black-box estimator by measuring how score decreases when a feature is not available.

# %%
import eli5
from eli5.sklearn import PermutationImportance
from timeit import default_timer as timer
from sklearn.ensemble import RandomForestClassifier
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# .datatable .frame thead tr.colnames {  background-image: url('data:image/png;base64,...');  background-repeat: repeat-x;  background-size: 14px;  height: 28px;}
# </style>

# %%
timeFirstI  = timer()
modelRF     = RandomForestClassifier(random_state = 42).fit(X_train, y_train)
perm        = PermutationImportance(modelRF, random_state = 42).fit(X_val, y_val)
timeSecondI = timer()

# %%
print("Total time with Intel Extension: {} seconds".format(timeSecondI - timeFirstI))
# Out:
# Total time with Intel Extension: 4236.698096521 seconds

# %%
eli5.show_weights(perm, feature_names = X.columns.tolist())
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.4542
#
#                     &plusmn; 0.0012
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Elevation
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.84%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0481
#
#                     &plusmn; 0.0006
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Horizontal_Distance_To_Roadways
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.84%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0326
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Horizontal_Distance_To_Fire_Points
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.40%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0247
#
#                     &plusmn; 0.0006
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Wilderness_Area3
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.76%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0199
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Wilderness_Area4
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.90%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0181
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Vertical_Distance_To_Hydrology
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.54%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0108
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Horizontal_Distance_To_Hydrology
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.74%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0087
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Soil_Type39
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.87%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0075
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Soil_Type38
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.99%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0064
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Wilderness_Area1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.15%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0050
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Soil_Type40
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.23%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0044
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Soil_Type10
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.34%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0035
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Soil_Type22
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.37%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0032
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Soil_Type23
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.43%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0028
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Soil_Type33
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.52%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0022
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Soil_Type35
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.56%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0020
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Soil_Type32
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.59%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-ali

# %%
pi_features = eli5.explain_weights_df(perm, feature_names = X_train.columns.tolist())
pi_features = pi_features.loc[pi_features['weight'] >= 0.0001]['feature'].tolist()

# %%
pi_features[:5]
# Out:
# ['Elevation',
#  'Horizontal_Distance_To_Roadways',
#  'Horizontal_Distance_To_Fire_Points',
#  'Wilderness_Area3',
#  'Wilderness_Area4']

# %%
X_trainPI = X_train.loc[:, pi_features]
X_valPI   = X_val.loc[:, pi_features]

# %%
X_trainPI[:5]
# Out:
#          Elevation  Horizontal_Distance_To_Roadways  \
# 1168622       3338                             1486
# 1528343       3306                             1387
# 159785        2984                             1860
# 2933315       3239                             3030
# 430775        2992                             2033
#
#          Horizontal_Distance_To_Fire_Points  Wilderness_Area3  \
# 1168622                                1778                 1
# 1528343                                 330                 0
# 159785                                 2348                 0
# 2933315                                2065                 0
# 430775                                 1180                 1
#
#          Wilderness_Area4  Vertical_Distance_To_Hydrology  \
# 1168622                 0                               1
# 1528343                 0                              20
# 159785                  0                               0
# 2933315                 0                             117
# 430775                  0                             183
#
#          Horizontal_Distance_To_Hydrology  Soil_Type39  Soil_Type38  \
# 1168622                               241            0            0
# 1528343                               218            0            0
# 159785                                893            0            0
# 2933315                               239            0            0
# 430775                                537            0            0
#
#          Wilderness_Area1  ...  Soil_Type27  Soil_Type34  Soil_Type21  \
# 1168622                 0  ...            0            0            0
# 1528343                 1  ...            0            0            0
# 159785                  1  ...            0            0            0
# 2933315                 0  ...            0            0            0
# 430775                  0  ...            0            0            0
#
#          Soil_Type28  Soil_Type9  Hillshade_Noon  Soil_Type29  \
# 1168622            0           0             206            0
# 1528343            0           0             201            0
# 159785             0           0             224            0
# 2933315            0           0             209            0
# 430775             0           0             246            0
#
#          Wilderness_Area2  Soil_Type4  Soil_Type25
# 1168622                 0           0            0
# 1528343                 0           0            0
# 159785                  0           0            0
# 2933315                 0           0            0
# 430775                  0           0            0
#
# [5 rows x 43 columns]

# %% [markdown]
# ### Accelerated functions:

# %%
# !cat log.txt | grep 'running accelerated version' | sort | uniq
# Out:
# sklearn.ensemble.RandomForestClassifier.fit: running accelerated version on CPU
# sklearn.ensemble.RandomForestClassifier.predict: running accelerated version on CPU
# sklearn.model_selection.train_test_split: running accelerated version on CPU

# %% [markdown]
# ### Default Scikit-learn

# %%
from sklearnex import unpatch_sklearn
unpatch_sklearn()

# %%
import eli5
from eli5.sklearn import PermutationImportance
from timeit import default_timer as timer
from sklearn.ensemble import RandomForestClassifier

# %%
timeFirstD  = timer()
modelRF     = RandomForestClassifier(random_state = 42).fit(X_train, y_train)
perm        = PermutationImportance(modelRF, random_state = 42).fit(X_val, y_val)
timeSecondD = timer()

# %%
print("Total time with default Scikit-learn: {} seconds".format(timeSecondD - timeFirstD))
# Out:
# Total time with default Scikit-learn: 5964.087305736 seconds

# %%
eli5.show_weights(perm, feature_names = X.columns.tolist())
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.4536
#
#                     &plusmn; 0.0013
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Elevation
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.92%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0468
#
#                     &plusmn; 0.0006
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Horizontal_Distance_To_Roadways
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.93%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0311
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Horizontal_Distance_To_Fire_Points
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.52%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0229
#
#                     &plusmn; 0.0006
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Wilderness_Area3
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.85%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0188
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Wilderness_Area4
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.96%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0173
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Vertical_Distance_To_Hydrology
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.61%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0100
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Horizontal_Distance_To_Hydrology
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.76%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0086
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Soil_Type39
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.79%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0083
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Wilderness_Area1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.88%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0073
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Soil_Type38
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.16%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0049
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Soil_Type40
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.24%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0043
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Soil_Type10
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.37%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0032
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Soil_Type22
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.39%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0031
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Soil_Type23
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.44%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0028
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Soil_Type33
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.53%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0021
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Soil_Type35
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.58%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0018
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Soil_Type32
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.61%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-ali

# %%
eli5_speedup = round((timeSecondD - timeFirstD) / (timeSecondI - timeFirstI), 2)
HTML(f'<h2>ELI5 speedup: {eli5_speedup}x</h2>'
     f'(from {round((timeSecondD - timeFirstD), 2)} to {round((timeSecondI - timeFirstI), 2)} seconds)')
# Out:
# <h2>ELI5 speedup: 1.41x</h2>(from 5964.09 to 4236.7 seconds)

# %% [markdown]
# <div style="background-color:rgba(0, 167, 255, 0.6);border-radius:5px;display:fill">
#     <h1><center>Catboost</center></h1>
# </div>

# %%
test_data = test_data.loc[:, pi_features]

# %%
from catboost import CatBoostClassifier

cat_params = {
    'iterations': 20000,
    'depth': 7,
    'task_type' : 'GPU',
    'l2_leaf_reg': 5,
    'eval_metric': 'Accuracy',
}

cat = CatBoostClassifier(**cat_params)
cat.fit(X_trainPI, y_train, eval_set=(X_valPI, y_val))
# Out:
# 0:	learn: 0.9029700	test: 0.9037500	best: 0.9037500 (0)	total: 52.9ms	remaining: 17m 37s
# 1:	learn: 0.9026928	test: 0.9036300	best: 0.9037500 (0)	total: 99.7ms	remaining: 16m 37s
# 2:	learn: 0.9049117	test: 0.9057725	best: 0.9057725 (2)	total: 147ms	remaining: 16m 16s
# 3:	learn: 0.9029819	test: 0.9038150	best: 0.9057725 (2)	total: 193ms	remaining: 16m 6s
# 4:	learn: 0.9052153	test: 0.9060800	best: 0.9060800 (4)	total: 246ms	remaining: 16m 22s
# 5:	learn: 0.9053919	test: 0.9062850	best: 0.9062850 (5)	total: 304ms	remaining: 16m 53s
# 6:	learn: 0.9055700	test: 0.9064450	best: 0.9064450 (6)	total: 350ms	remaining: 16m 39s
# 7:	learn: 0.9057889	test: 0.9066475	best: 0.9066475 (7)	total: 395ms	remaining: 16m 27s
# 8:	learn: 0.9058767	test: 0.9066775	best: 0.9066775 (8)	total: 442ms	remaining: 16m 22s
# 9:	learn: 0.9057908	test: 0.9066150	best: 0.9066775 (8)	total: 487ms	remaining: 16m 14s
# 10:	learn: 0.9057833	test: 0.9066050	best: 0.9066775 (8)	total: 534ms	remaining: 16m 10s
# 11:	learn: 0.9057778	test: 0.9065850	best: 0.9066775 (8)	total: 579ms	remaining: 16m 3s
# 12:	learn: 0.9057611	test: 0.9065375	best: 0.9066775 (8)	total: 623ms	remaining: 15m 57s
# 13:	learn: 0.9059825	test: 0.9068375	best: 0.9068375 (13)	total: 667ms	remaining: 15m 52s
# 14:	learn: 0.9060742	test: 0.9069575	best: 0.9069575 (14)	total: 712ms	remaining: 15m 48s
# 15:	learn: 0.9062042	test: 0.9070800	best: 0.9070800 (15)	total: 759ms	remaining: 15m 47s
# 16:	learn: 0.9062233	test: 0.9070925	best: 0.9070925 (16)	total: 803ms	remaining: 15m 44s
# 17:	learn: 0.9063944	test: 0.9072825	best: 0.9072825 (17)	total: 890ms	remaining: 16m 27s
# 18:	learn: 0.9064050	test: 0.9072500	best: 0.9072825 (17)	total: 934ms	remaining: 16m 22s
# 19:	learn: 0.9064233	test: 0.9073050	best: 0.9073050 (19)	total: 979ms	remaining: 16m 18s
# 20:	learn: 0.9064042	test: 0.9072900	best: 0.9073050 (19)	total: 1.02s	remaining: 16m 14s
# 21:	learn: 0.9064953	test: 0.9074300	best: 0.9074300 (21)	total: 1.07s	remaining: 16m 10s
# 22:	learn: 0.9064742	test: 0.9074075	best: 0.9074300 (21)	total: 1.11s	remaining: 16m 6s
# 23:	learn: 0.9064450	test: 0.9073975	best: 0.9074300 (21)	total: 1.16s	remaining: 16m 3s
# 24:	learn: 0.9064772	test: 0.9073950	best: 0.9074300 (21)	total: 1.2s	remaining: 16m 2s
# 25:	learn: 0.9067969	test: 0.9077325	best: 0.9077325 (25)	total: 1.25s	remaining: 16m
# 26:	learn: 0.9068903	test: 0.9077200	best: 0.9077325 (25)	total: 1.29s	remaining: 15m 57s
# 27:	learn: 0.9069272	test: 0.9077250	best: 0.9077325 (25)	total: 1.34s	remaining: 15m 55s
# 28:	learn: 0.9071306	test: 0.9080725	best: 0.9080725 (28)	total: 1.39s	remaining: 15m 54s
# 29:	learn: 0.9071847	test: 0.9080875	best: 0.9080875 (29)	total: 1.43s	remaining: 15m 52s
# 30:	learn: 0.9073458	test: 0.9081875	best: 0.9081875 (30)	total: 1.48s	remaining: 15m 50s
# 31:	learn: 0.9076383	test: 0.9085150	best: 0.9085150 (31)	total: 1.52s	remaining: 15m 49s
# 32:	learn: 0.9077367	test: 0.9086050	best: 0.9086050 (32)	total: 1.57s	remaining: 15m 48s
# 33:	learn: 0.9078889	test: 0.9087175	best: 0.9087175 (33)	total: 1.61s	remaining: 15m 47s
# 34:	learn: 0.9079947	test: 0.9089125	best: 0.9089125 (34)	total: 1.66s	remaining: 15m 47s
# 35:	learn: 0.9081961	test: 0.9090750	best: 0.9090750 (35)	total: 1.71s	remaining: 15m 46s
# 36:	learn: 0.9082833	test: 0.9091900	best: 0.9091900 (36)	total: 1.76s	remaining: 15m 51s
# 37:	learn: 0.9083167	test: 0.9091975	best: 0.9091975 (37)	total: 1.81s	remaining: 15m 49s
# 38:	learn: 0.9084686	test: 0.9093825	best: 0.9093825 (38)	total: 1.85s	remaining: 15m 48s
# 39:	learn: 0.9087231	test: 0.9096650	best: 0.9096650 (39)	total: 1.9s	remaining: 15m 49s
# 40:	learn: 0.9088547	test: 0.9097675	best: 0.9097675 (40)	total: 1.95s	remaining: 15m 49s
# 41:	learn: 0.9091383	test: 0.9101800	best: 0.9101800 (41)	total: 1.99s	remaining: 15m 46s
# 42:	learn: 0.9092344	test: 0.9102375	best: 0.9102375 (42)	total: 2.04s	remaining: 15m 45s
# 43:	learn: 0.9091644	test: 0.9099800	best: 0.9102375 (42)	total: 2.08s	remaining: 15m 43s
# 44:	learn: 0.9092156	test: 0.9100475	best: 0.9102375 (42)	total: 2.13s	remaining: 15m 42s
# 45:	learn: 0.9094517	test: 0.9103925	best: 0.9103925 (45)	total: 2.17s	remaining: 15m 42s
# 46:	learn: 0.9095372	test: 0.9105375	best: 0.9105375 (46)	total: 2.22s	remaining: 15m 42s
# 47:	learn: 0.9097425	test: 0.9106725	best: 0.9106725 (47)	total: 2.27s	remaining: 15m 42s
# 104:	learn: 0.9163064	test: 0.9170475	best: 0.9170475 (104)	total: 4.95s	remaining: 15m 37s
# 105:	learn: 0.9164153	test: 0.9171675	best: 0.9171675 (105)	total: 4.99s	remaining: 15m 36s
# 106:	learn: 0.9165844	test: 0.9173775	best: 0.9173775 (106)	total: 5.04s	remaining: 15m 37s
# 107:	learn: 0.9167714	test: 0.9175200	best: 0.9175200 (107)	total: 5.09s	remaining: 15m 37s
# 108:	learn: 0.9168825	test: 0.9176725	best: 0.9176725 (108)	total: 5.13s	remaining: 15m 36s
# 109:	learn: 0.9169722	test: 0.9177500	best: 0.9177500 (109)	total: 5.18s	remaining: 15m 36s
# 110:	learn: 0.9171636	test: 0.9179750	best: 0.9179750 (110)	total: 5.23s	remaining: 15m 36s
# 111:	learn: 0.9173742	test: 0.9181450	best: 0.9181450 (111)	total: 5.28s	remaining: 15m 36s
# 112:	learn: 0.9175736	test: 0.9183700	best: 0.9183700 (112)	total: 5.32s	remaining: 15m 36s
# 113:	learn: 0.9176550	test: 0.9184300	best: 0.9184300 (113)	total: 5.37s	remaining: 15m 36s
# 114:	learn: 0.9177708	test: 0.9186000	best: 0.9186000 (114)	total: 5.42s	remaining: 15m 36s
# 115:	learn: 0.9178675	test: 0.9186450	best: 0.9186450 (115)	total: 5.46s	remaining: 15m 36s
# 116:	learn: 0.9179508	test: 0.9187600	best: 0.9187600 (116)	total: 5.51s	remaining: 15m 36s
# 117:	learn: 0.9181606	test: 0.9189300	best: 0.9189300 (117)	total: 5.55s	remaining: 15m 35s
# 118:	learn: 0.9182769	test: 0.9190450	best: 0.9190450 (118)	total: 5.6s	remaining: 15m 35s
# 119:	learn: 0.9183519	test: 0.9191525	best: 0.9191525 (119)	total: 5.64s	remaining: 15m 35s
# 120:	learn: 0.9185167	test: 0.9192775	best: 0.9192775 (120)	total: 5.69s	remaining: 15m 35s
# 121:	learn: 0.9186719	test: 0.9193825	best: 0.9193825 (121)	total: 5.74s	remaining: 15m 35s
# 122:	learn: 0.9187886	test: 0.9194775	best: 0.9194775 (122)	total: 5.82s	remaining: 15m 39s
# 123:	learn: 0.9189775	test: 0.9196600	best: 0.9196600 (123)	total: 5.9s	remaining: 15m 45s
# 124:	learn: 0.9190681	test: 0.9197325	best: 0.9197325 (124)	total: 5.99s	remaining: 15m 52s
# 125:	learn: 0.9192078	test: 0.9199150	best: 0.9199150 (125)	total: 6.08s	remaining: 15m 59s
# 126:	learn: 0.9193122	test: 0.9200325	best: 0.9200325 (126)	total: 6.13s	remaining: 16m
# 127:	learn: 0.9193733	test: 0.9201250	best: 0.9201250 (127)	total: 6.22s	remaining: 16m 6s
# 128:	learn: 0.9195353	test: 0.9202475	best: 0.9202475 (128)	total: 6.31s	remaining: 16m 12s
# 129:	learn: 0.9196708	test: 0.9203925	best: 0.9203925 (129)	total: 6.39s	remaining: 16m 16s
# 130:	learn: 0.9197947	test: 0.9205175	best: 0.9205175 (130)	total: 6.43s	remaining: 16m 15s
# 131:	learn: 0.9199789	test: 0.9207100	best: 0.9207100 (131)	total: 6.48s	remaining: 16m 15s
# 132:	learn: 0.9202122	test: 0.9209800	best: 0.9209800 (132)	total: 6.54s	remaining: 16m 16s
# 133:	learn: 0.9202694	test: 0.9210525	best: 0.9210525 (133)	total: 6.59s	remaining: 16m 17s
# 134:	learn: 0.9204911	test: 0.9213325	best: 0.9213325 (134)	total: 6.64s	remaining: 16m 16s
# 135:	learn: 0.9206128	test: 0.9215200	best: 0.9215200 (135)	total: 6.68s	remaining: 16m 16s
# 136:	learn: 0.9208192	test: 0.9216700	best: 0.9216700 (136)	total: 6.73s	remaining: 16m 15s
# 137:	learn: 0.9209917	test: 0.9218175	best: 0.9218175 (137)	total: 6.78s	remaining: 16m 15s
# 138:	learn: 0.9213147	test: 0.9220800	best: 0.9220800 (138)	total: 6.82s	remaining: 16m 14s
# 139:	learn: 0.9215303	test: 0.9222775	best: 0.9222775 (139)	total: 6.87s	remaining: 16m 14s
# 140:	learn: 0.9218239	test: 0.9225700	best: 0.9225700 (140)	total: 6.91s	remaining: 16m 13s
# 141:	learn: 0.9219803	test: 0.9227400	best: 0.9227400 (141)	total: 6.96s	remaining: 16m 13s
# 142:	learn: 0.9222597	test: 0.9230275	best: 0.9230275 (142)	total: 7.01s	remaining: 16m 12s
# 143:	learn: 0.9224975	test: 0.9232950	best: 0.9232950 (143)	total: 7.05s	remaining: 16m 12s
# 144:	learn: 0.9226450	test: 0.9234350	best: 0.9234350 (144)	total: 7.1s	remaining: 16m 12s
# 145:	learn: 0.9228708	test: 0.9237075	best: 0.9237075 (145)	total: 7.14s	remaining: 16m 11s
# 146:	learn: 0.9230067	test: 0.9237750	best: 0.9237750 (146)	total: 7.19s	remaining: 16m 10s
# 147:	learn: 0.9233664	test: 0.9242025	best: 0.9242025 (147)	total: 7.24s	remaining: 16m 10s
# 148:	learn: 0.9237161	test: 0.9244950	best: 0.9244950 (148)	total: 7.28s	remaining: 16m 10s
# 149:	learn: 0.9239744	test: 0.9247625	best: 0.9247625 (149)	total: 7.33s	remaining: 16m 9s
# 150:	learn: 0.9241258	test: 0.9249175	best: 0.9249175 (150)	total: 7.37s	remaining: 16m 9s
# 151:	learn: 0.9241925	test: 0.9249125	best: 0.9249175 (150)	total: 7.42s	remaining: 16m 8s
# 152:	learn: 0.9244556	test: 0.9251850	best: 0.9251850 (152)	total: 7.47s	remaining: 16m 8s
# 153:	learn: 0.9245961	test: 0.9253675	best: 0.9253675 (153)	total: 7.51s	remaining: 16m 8s
# 154:	learn: 0.9247744	test: 0.9255650	best: 0.9255650 (154)	total: 7.56s	remaining: 16m 7s
# 155:	learn: 0.9249481	test: 0.9257375	best: 0.9257375 (155)	total: 7.6s	remaining: 16m 7s
# 156:	learn: 0.9250919	test: 0.9258750	best: 0.9258750 (156)	total: 7.64s	remaining: 16m 6s
# 157:	learn: 0.9252903	test: 0.9261225	best: 0.9261225 (157)	total: 7.69s	remaining: 16m 5s
# 158:	learn: 0.9253611	test: 0.9262000	best: 0.9262000 (158)	total: 7.74s	remaining: 16m 5s
# 159:	learn: 0.9255161	test: 0.9263175	best: 0.9263175 (159)	total: 7.78s	remaining: 16m 5s
# 188:	learn: 0.9297125	test: 0.9305350	best: 0.9305350 (188)	total: 9.14s	remaining: 15m 57s
# 189:	learn: 0.9298042	test: 0.9305975	best: 0.9305975 (189)	total: 9.19s	remaining: 15m 57s
# 190:	learn: 0.9299450	test: 0.9307900	best: 0.9307900 (190)	total: 9.23s	remaining: 15m 56s
# 191:	learn: 0.9300181	test: 0.9308375	best: 0.9308375 (191)	total: 9.27s	remaining: 15m 56s
# 192:	learn: 0.9301722	test: 0.9309800	best: 0.9309800 (192)	total: 9.32s	remaining: 15m 56s
# 193:	learn: 0.9303383	test: 0.9312075	best: 0.9312075 (193)	total: 9.37s	remaining: 15m 56s
# 194:	learn: 0.9304781	test: 0.9313875	best: 0.9313875 (194)	total: 9.42s	remaining: 15m 57s
# 195:	learn: 0.9307589	test: 0.9315575	best: 0.9315575 (195)	total: 9.47s	remaining: 15m 56s
# 196:	learn: 0.9308264	test: 0.9316600	best: 0.9316600 (196)	total: 9.51s	remaining: 15m 56s
# 197:	learn: 0.9309500	test: 0.9318300	best: 0.9318300 (197)	total: 9.56s	remaining: 15m 55s
# 198:	learn: 0.9311225	test: 0.9320200	best: 0.9320200 (198)	total: 9.61s	remaining: 15m 55s
# 199:	learn: 0.9312983	test: 0.9321725	best: 0.9321725 (199)	total: 9.65s	remaining: 15m 55s
# 200:	learn: 0.9315131	test: 0.9323725	best: 0.9323725 (200)	total: 9.69s	remaining: 15m 54s
# 201:	learn: 0.9316139	test: 0.9324275	best: 0.9324275 (201)	total: 9.74s	remaining: 15m 54s
# 202:	learn: 0.9317039	test: 0.9324950	best: 0.9324950 (202)	total: 9.79s	remaining: 15m 54s
# 203:	learn: 0.9318589	test: 0.9326525	best: 0.9326525 (203)	total: 9.84s	remaining: 15m 54s
# 204:	learn: 0.9320275	test: 0.9328200	best: 0.9328200 (204)	total: 9.88s	remaining: 15m 53s
# 205:	learn: 0.9321686	test: 0.9329650	best: 0.9329650 (205)	total: 9.92s	remaining: 15m 53s
# 206:	learn: 0.9322158	test: 0.9330600	best: 0.9330600 (206)	total: 9.97s	remaining: 15m 53s
# 207:	learn: 0.9322425	test: 0.9330400	best: 0.9330600 (206)	total: 10s	remaining: 15m 52s
# 208:	learn: 0.9324475	test: 0.9332600	best: 0.9332600 (208)	total: 10.1s	remaining: 15m 52s
# 209:	learn: 0.9325583	test: 0.9334100	best: 0.9334100 (209)	total: 10.1s	remaining: 15m 52s
# 210:	learn: 0.9326794	test: 0.9335450	best: 0.9335450 (210)	total: 10.1s	remaining: 15m 51s
# 211:	learn: 0.9328056	test: 0.9336975	best: 0.9336975 (211)	total: 10.2s	remaining: 15m 51s
# 212:	learn: 0.9328842	test: 0.9337425	best: 0.9337425 (212)	total: 10.2s	remaining: 15m 51s
# 213:	learn: 0.9329628	test: 0.9338300	best: 0.9338300 (213)	total: 10.3s	remaining: 15m 50s
# 214:	learn: 0.9330400	test: 0.9339100	best: 0.9339100 (214)	total: 10.3s	remaining: 15m 50s
# 215:	learn: 0.9331406	test: 0.9340250	best: 0.9340250 (215)	total: 10.4s	remaining: 15m 50s
# 216:	learn: 0.9332289	test: 0.9340950	best: 0.9340950 (216)	total: 10.4s	remaining: 15m 49s
# 217:	learn: 0.9333308	test: 0.9341650	best: 0.9341650 (217)	total: 10.5s	remaining: 15m 49s
# 218:	learn: 0.9334167	test: 0.9342450	best: 0.9342450 (218)	total: 10.5s	remaining: 15m 49s
# 219:	learn: 0.9335114	test: 0.9343625	best: 0.9343625 (219)	total: 10.5s	remaining: 15m 48s
# 220:	learn: 0.9335839	test: 0.9344625	best: 0.9344625 (220)	total: 10.6s	remaining: 15m 48s
# 221:	learn: 0.9337725	test: 0.9346125	best: 0.9346125 (221)	total: 10.6s	remaining: 15m 48s
# 222:	learn: 0.9338539	test: 0.9347275	best: 0.9347275 (222)	total: 10.7s	remaining: 15m 47s
# 223:	learn: 0.9339300	test: 0.9347900	best: 0.9347900 (223)	total: 10.7s	remaining: 15m 48s
# 224:	learn: 0.9339922	test: 0.9348650	best: 0.9348650 (224)	total: 10.8s	remaining: 15m 48s
# 225:	learn: 0.9340922	test: 0.9349400	best: 0.9349400 (225)	total: 10.8s	remaining: 15m 47s
# 226:	learn: 0.9342175	test: 0.9350075	best: 0.9350075 (226)	total: 10.9s	remaining: 15m 47s
# 227:	learn: 0.9342572	test: 0.9350750	best: 0.9350750 (227)	total: 10.9s	remaining: 15m 47s
# 228:	learn: 0.9343950	test: 0.9351925	best: 0.9351925 (228)	total: 11s	remaining: 15m 47s
# 229:	learn: 0.9344439	test: 0.9352425	best: 0.9352425 (229)	total: 11s	remaining: 15m 47s
# 230:	learn: 0.9345403	test: 0.9353825	best: 0.9353825 (230)	total: 11.1s	remaining: 15m 47s
# 231:	learn: 0.9345886	test: 0.9354375	best: 0.9354375 (231)	total: 11.1s	remaining: 15m 47s
# 232:	learn: 0.9346475	test: 0.9354950	best: 0.9354950 (232)	total: 11.2s	remaining: 15m 46s
# 233:	learn: 0.9346986	test: 0.9356025	best: 0.9356025 (233)	total: 11.2s	remaining: 15m 46s
# 234:	learn: 0.9347717	test: 0.9356400	best: 0.9356400 (234)	total: 11.3s	remaining: 15m 46s
# 235:	learn: 0.9348197	test: 0.9356575	best: 0.9356575 (235)	total: 11.3s	remaining: 15m 46s
# 236:	learn: 0.9348928	test: 0.9357375	best: 0.9357375 (236)	total: 11.3s	remaining: 15m 46s
# 237:	learn: 0.9349750	test: 0.9358500	best: 0.9358500 (237)	total: 11.4s	remaining: 15m 46s
# 238:	learn: 0.9350617	test: 0.9359075	best: 0.9359075 (238)	total: 11.4s	remaining: 15m 46s
# 239:	learn: 0.9350969	test: 0.9359450	best: 0.9359450 (239)	total: 11.5s	remaining: 15m 45s
# 240:	learn: 0.9351981	test: 0.9360500	best: 0.9360500 (240)	total: 11.5s	remaining: 15m 45s
# 241:	learn: 0.9353039	test: 0.9361450	best: 0.9361450 (241)	total: 11.6s	remaining: 15m 44s
# 242:	learn: 0.9353836	test: 0.9362575	best: 0.9362575 (242)	total: 11.6s	remaining: 15m 44s
# 243:	learn: 0.9354308	test: 0.9362825	best: 0.9362825 (243)	total: 11.7s	remaining: 15m 44s
# 300:	learn: 0.9394272	test: 0.9401850	best: 0.9401850 (300)	total: 14.3s	remaining: 15m 34s
# 301:	learn: 0.9395069	test: 0.9402250	best: 0.9402250 (301)	total: 14.3s	remaining: 15m 34s
# 302:	learn: 0.9395614	test: 0.9402900	best: 0.9402900 (302)	total: 14.4s	remaining: 15m 33s
# 303:	learn: 0.9395972	test: 0.9403275	best: 0.9403275 (303)	total: 14.4s	remaining: 15m 33s
# 304:	learn: 0.9396586	test: 0.9403800	best: 0.9403800 (304)	total: 14.5s	remaining: 15m 33s
# 305:	learn: 0.9397072	test: 0.9404125	best: 0.9404125 (305)	total: 14.5s	remaining: 15m 33s
# 306:	learn: 0.9397414	test: 0.9404475	best: 0.9404475 (306)	total: 14.6s	remaining: 15m 33s
# 307:	learn: 0.9397733	test: 0.9404725	best: 0.9404725 (307)	total: 14.6s	remaining: 15m 33s
# 308:	learn: 0.9398508	test: 0.9405475	best: 0.9405475 (308)	total: 14.6s	remaining: 15m 33s
# 309:	learn: 0.9398933	test: 0.9406050	best: 0.9406050 (309)	total: 14.7s	remaining: 15m 33s
# 310:	learn: 0.9399533	test: 0.9406425	best: 0.9406425 (310)	total: 14.7s	remaining: 15m 32s
# 311:	learn: 0.9399944	test: 0.9407275	best: 0.9407275 (311)	total: 14.8s	remaining: 15m 32s
# 312:	learn: 0.9400239	test: 0.9408400	best: 0.9408400 (312)	total: 14.8s	remaining: 15m 32s
# 313:	learn: 0.9400731	test: 0.9408600	best: 0.9408600 (313)	total: 14.9s	remaining: 15m 32s
# 314:	learn: 0.9401508	test: 0.9408925	best: 0.9408925 (314)	total: 14.9s	remaining: 15m 32s
# 315:	learn: 0.9402122	test: 0.9409375	best: 0.9409375 (315)	total: 15s	remaining: 15m 32s
# 316:	learn: 0.9402586	test: 0.9409925	best: 0.9409925 (316)	total: 15s	remaining: 15m 32s
# 317:	learn: 0.9403186	test: 0.9410450	best: 0.9410450 (317)	total: 15.1s	remaining: 15m 31s
# 318:	learn: 0.9403717	test: 0.9410700	best: 0.9410700 (318)	total: 15.1s	remaining: 15m 31s
# 319:	learn: 0.9404394	test: 0.9411200	best: 0.9411200 (319)	total: 15.1s	remaining: 15m 31s
# 320:	learn: 0.9404603	test: 0.9411475	best: 0.9411475 (320)	total: 15.2s	remaining: 15m 31s
# 321:	learn: 0.9405175	test: 0.9412425	best: 0.9412425 (321)	total: 15.2s	remaining: 15m 31s
# 322:	learn: 0.9405567	test: 0.9412850	best: 0.9412850 (322)	total: 15.3s	remaining: 15m 30s
# 323:	learn: 0.9406072	test: 0.9413900	best: 0.9413900 (323)	total: 15.3s	remaining: 15m 30s
# 324:	learn: 0.9406881	test: 0.9414625	best: 0.9414625 (324)	total: 15.4s	remaining: 15m 30s
# 325:	learn: 0.9407522	test: 0.9415375	best: 0.9415375 (325)	total: 15.4s	remaining: 15m 30s
# 326:	learn: 0.9407997	test: 0.9416075	best: 0.9416075 (326)	total: 15.5s	remaining: 15m 30s
# 327:	learn: 0.9408528	test: 0.9416925	best: 0.9416925 (327)	total: 15.5s	remaining: 15m 30s
# 328:	learn: 0.9408956	test: 0.9417175	best: 0.9417175 (328)	total: 15.6s	remaining: 15m 30s
# 329:	learn: 0.9409325	test: 0.9417175	best: 0.9417175 (328)	total: 15.6s	remaining: 15m 29s
# 330:	learn: 0.9409681	test: 0.9417525	best: 0.9417525 (330)	total: 15.6s	remaining: 15m 29s
# 331:	learn: 0.9410525	test: 0.9418425	best: 0.9418425 (331)	total: 15.7s	remaining: 15m 29s
# 332:	learn: 0.9411078	test: 0.9419050	best: 0.9419050 (332)	total: 15.7s	remaining: 15m 29s
# 333:	learn: 0.9411703	test: 0.9419850	best: 0.9419850 (333)	total: 15.8s	remaining: 15m 29s
# 334:	learn: 0.9412189	test: 0.9419825	best: 0.9419850 (333)	total: 15.8s	remaining: 15m 29s
# 335:	learn: 0.9412875	test: 0.9420700	best: 0.9420700 (335)	total: 15.9s	remaining: 15m 29s
# 336:	learn: 0.9413106	test: 0.9420925	best: 0.9420925 (336)	total: 15.9s	remaining: 15m 29s
# 337:	learn: 0.9413917	test: 0.9421900	best: 0.9421900 (337)	total: 16s	remaining: 15m 29s
# 338:	learn: 0.9414739	test: 0.9423175	best: 0.9423175 (338)	total: 16s	remaining: 15m 29s
# 339:	learn: 0.9415242	test: 0.9423775	best: 0.9423775 (339)	total: 16.1s	remaining: 15m 29s
# 340:	learn: 0.9415556	test: 0.9424150	best: 0.9424150 (340)	total: 16.1s	remaining: 15m 28s
# 341:	learn: 0.9415897	test: 0.9424725	best: 0.9424725 (341)	total: 16.2s	remaining: 15m 28s
# 342:	learn: 0.9416233	test: 0.9425150	best: 0.9425150 (342)	total: 16.2s	remaining: 15m 28s
# 343:	learn: 0.9416467	test: 0.9425425	best: 0.9425425 (343)	total: 16.3s	remaining: 15m 28s
# 344:	learn: 0.9416911	test: 0.9425600	best: 0.9425600 (344)	total: 16.3s	remaining: 15m 28s
# 345:	learn: 0.9417217	test: 0.9425650	best: 0.9425650 (345)	total: 16.3s	remaining: 15m 28s
# 346:	learn: 0.9417886	test: 0.9426400	best: 0.9426400 (346)	total: 16.4s	remaining: 15m 28s
# 347:	learn: 0.9418608	test: 0.9427000	best: 0.9427000 (347)	total: 16.4s	remaining: 15m 28s
# 348:	learn: 0.9419242	test: 0.9427925	best: 0.9427925 (348)	total: 16.5s	remaining: 15m 28s
# 349:	learn: 0.9419817	test: 0.9428350	best: 0.9428350 (349)	total: 16.5s	remaining: 15m 28s
# 350:	learn: 0.9420156	test: 0.9428675	best: 0.9428675 (350)	total: 16.6s	remaining: 15m 28s
# 351:	learn: 0.9420900	test: 0.9429275	best: 0.9429275 (351)	total: 16.7s	remaining: 15m 30s
# 352:	learn: 0.9421181	test: 0.9429400	best: 0.9429400 (352)	total: 16.8s	remaining: 15m 33s
# 353:	learn: 0.9421550	test: 0.9429625	best: 0.9429625 (353)	total: 16.9s	remaining: 15m 38s
# 354:	learn: 0.9421936	test: 0.9429875	best: 0.9429875 (354)	total: 17s	remaining: 15m 43s
# 355:	learn: 0.9422264	test: 0.9430675	best: 0.9430675 (355)	total: 17.2s	remaining: 15m 47s
# 384:	learn: 0.9436028	test: 0.9445050	best: 0.9445050 (384)	total: 19.1s	remaining: 16m 10s
# 385:	learn: 0.9436489	test: 0.9445325	best: 0.9445325 (385)	total: 19.1s	remaining: 16m 10s
# 386:	learn: 0.9436808	test: 0.9445750	best: 0.9445750 (386)	total: 19.1s	remaining: 16m 10s
# 387:	learn: 0.9437242	test: 0.9446075	best: 0.9446075 (387)	total: 19.2s	remaining: 16m 10s
# 388:	learn: 0.9437914	test: 0.9446600	best: 0.9446600 (388)	total: 19.2s	remaining: 16m 9s
# 389:	learn: 0.9438178	test: 0.9446650	best: 0.9446650 (389)	total: 19.3s	remaining: 16m 9s
# 390:	learn: 0.9438689	test: 0.9446875	best: 0.9446875 (390)	total: 19.3s	remaining: 16m 9s
# 391:	learn: 0.9439181	test: 0.9447375	best: 0.9447375 (391)	total: 19.4s	remaining: 16m 8s
# 392:	learn: 0.9439981	test: 0.9448000	best: 0.9448000 (392)	total: 19.4s	remaining: 16m 8s
# 393:	learn: 0.9440844	test: 0.9448750	best: 0.9448750 (393)	total: 19.5s	remaining: 16m 8s
# 394:	learn: 0.9441075	test: 0.9449300	best: 0.9449300 (394)	total: 19.5s	remaining: 16m 8s
# 395:	learn: 0.9441453	test: 0.9449750	best: 0.9449750 (395)	total: 19.6s	remaining: 16m 8s
# 396:	learn: 0.9442003	test: 0.9450375	best: 0.9450375 (396)	total: 19.6s	remaining: 16m 8s
# 397:	learn: 0.9442419	test: 0.9450775	best: 0.9450775 (397)	total: 19.7s	remaining: 16m 8s
# 398:	learn: 0.9442853	test: 0.9451325	best: 0.9451325 (398)	total: 19.7s	remaining: 16m 7s
# 399:	learn: 0.9443317	test: 0.9451550	best: 0.9451550 (399)	total: 19.7s	remaining: 16m 7s
# 400:	learn: 0.9444036	test: 0.9452025	best: 0.9452025 (400)	total: 19.8s	remaining: 16m 7s
# 401:	learn: 0.9444478	test: 0.9452550	best: 0.9452550 (401)	total: 19.8s	remaining: 16m 6s
# 402:	learn: 0.9444639	test: 0.9452450	best: 0.9452550 (401)	total: 19.9s	remaining: 16m 6s
# 403:	learn: 0.9444994	test: 0.9453100	best: 0.9453100 (403)	total: 19.9s	remaining: 16m 6s
# 404:	learn: 0.9445469	test: 0.9453325	best: 0.9453325 (404)	total: 20s	remaining: 16m 6s
# 405:	learn: 0.9445786	test: 0.9453875	best: 0.9453875 (405)	total: 20s	remaining: 16m 6s
# 406:	learn: 0.9446764	test: 0.9454800	best: 0.9454800 (406)	total: 20.1s	remaining: 16m 6s
# 407:	learn: 0.9447222	test: 0.9454725	best: 0.9454800 (406)	total: 20.1s	remaining: 16m 5s
# 408:	learn: 0.9447750	test: 0.9455450	best: 0.9455450 (408)	total: 20.2s	remaining: 16m 5s
# 409:	learn: 0.9448233	test: 0.9456175	best: 0.9456175 (409)	total: 20.2s	remaining: 16m 5s
# 410:	learn: 0.9448550	test: 0.9456925	best: 0.9456925 (410)	total: 20.3s	remaining: 16m 5s
# 411:	learn: 0.9449214	test: 0.9457475	best: 0.9457475 (411)	total: 20.3s	remaining: 16m 5s
# 412:	learn: 0.9449706	test: 0.9457925	best: 0.9457925 (412)	total: 20.3s	remaining: 16m 4s
# 413:	learn: 0.9450153	test: 0.9458325	best: 0.9458325 (413)	total: 20.4s	remaining: 16m 4s
# 414:	learn: 0.9450375	test: 0.9458850	best: 0.9458850 (414)	total: 20.4s	remaining: 16m 4s
# 415:	learn: 0.9450708	test: 0.9458975	best: 0.9458975 (415)	total: 20.5s	remaining: 16m 4s
# 416:	learn: 0.9451169	test: 0.9459650	best: 0.9459650 (416)	total: 20.5s	remaining: 16m 3s
# 417:	learn: 0.9451731	test: 0.9460125	best: 0.9460125 (417)	total: 20.6s	remaining: 16m 3s
# 418:	learn: 0.9452019	test: 0.9460325	best: 0.9460325 (418)	total: 20.6s	remaining: 16m 3s
# 419:	learn: 0.9452361	test: 0.9460875	best: 0.9460875 (419)	total: 20.7s	remaining: 16m 3s
# 420:	learn: 0.9452683	test: 0.9461175	best: 0.9461175 (420)	total: 20.7s	remaining: 16m 3s
# 421:	learn: 0.9453161	test: 0.9461300	best: 0.9461300 (421)	total: 20.8s	remaining: 16m 3s
# 422:	learn: 0.9453417	test: 0.9461800	best: 0.9461800 (422)	total: 20.8s	remaining: 16m 3s
# 423:	learn: 0.9454122	test: 0.9462525	best: 0.9462525 (423)	total: 20.9s	remaining: 16m 3s
# 424:	learn: 0.9454403	test: 0.9462375	best: 0.9462525 (423)	total: 20.9s	remaining: 16m 2s
# 425:	learn: 0.9454692	test: 0.9462575	best: 0.9462575 (425)	total: 20.9s	remaining: 16m 2s
# 426:	learn: 0.9455264	test: 0.9463325	best: 0.9463325 (426)	total: 21s	remaining: 16m 2s
# 427:	learn: 0.9455389	test: 0.9463825	best: 0.9463825 (427)	total: 21s	remaining: 16m 2s
# 428:	learn: 0.9455569	test: 0.9463775	best: 0.9463825 (427)	total: 21.1s	remaining: 16m 2s
# 429:	learn: 0.9456242	test: 0.9464600	best: 0.9464600 (429)	total: 21.1s	remaining: 16m 1s
# 430:	learn: 0.9456453	test: 0.9465050	best: 0.9465050 (430)	total: 21.2s	remaining: 16m 1s
# 431:	learn: 0.9457133	test: 0.9465800	best: 0.9465800 (431)	total: 21.2s	remaining: 16m 1s
# 432:	learn: 0.9457244	test: 0.9466025	best: 0.9466025 (432)	total: 21.3s	remaining: 16m 1s
# 433:	learn: 0.9457578	test: 0.9466350	best: 0.9466350 (433)	total: 21.3s	remaining: 16m 1s
# 434:	learn: 0.9458089	test: 0.9467150	best: 0.9467150 (434)	total: 21.4s	remaining: 16m
# 435:	learn: 0.9458692	test: 0.9467850	best: 0.9467850 (435)	total: 21.4s	remaining: 16m
# 436:	learn: 0.9459269	test: 0.9468550	best: 0.9468550 (436)	total: 21.5s	remaining: 16m
# 437:	learn: 0.9459836	test: 0.9468800	best: 0.9468800 (437)	total: 21.5s	remaining: 16m
# 438:	learn: 0.9460189	test: 0.9469175	best: 0.9469175 (438)	total: 21.5s	remaining: 16m
# 439:	learn: 0.9460592	test: 0.9469275	best: 0.9469275 (439)	total: 21.6s	remaining: 15m 59s
# 440:	learn: 0.9461281	test: 0.9469850	best: 0.9469850 (440)	total: 21.6s	remaining: 15m 59s
# 497:	learn: 0.9480553	test: 0.9488100	best: 0.9488100 (497)	total: 24.2s	remaining: 15m 49s
# 498:	learn: 0.9480947	test: 0.9488825	best: 0.9488825 (498)	total: 24.3s	remaining: 15m 49s
# 499:	learn: 0.9481217	test: 0.9489050	best: 0.9489050 (499)	total: 24.3s	remaining: 15m 49s
# 500:	learn: 0.9481783	test: 0.9489825	best: 0.9489825 (500)	total: 24.4s	remaining: 15m 48s
# 501:	learn: 0.9482261	test: 0.9490575	best: 0.9490575 (501)	total: 24.4s	remaining: 15m 48s
# 502:	learn: 0.9482625	test: 0.9490850	best: 0.9490850 (502)	total: 24.5s	remaining: 15m 48s
# 503:	learn: 0.9483039	test: 0.9491200	best: 0.9491200 (503)	total: 24.5s	remaining: 15m 48s
# 504:	learn: 0.9483533	test: 0.9491425	best: 0.9491425 (504)	total: 24.6s	remaining: 15m 48s
# 505:	learn: 0.9483789	test: 0.9491550	best: 0.9491550 (505)	total: 24.6s	remaining: 15m 48s
# 506:	learn: 0.9484111	test: 0.9491575	best: 0.9491575 (506)	total: 24.7s	remaining: 15m 48s
# 507:	learn: 0.9484550	test: 0.9491925	best: 0.9491925 (507)	total: 24.7s	remaining: 15m 48s
# 508:	learn: 0.9484872	test: 0.9492475	best: 0.9492475 (508)	total: 24.8s	remaining: 15m 48s
# 509:	learn: 0.9485178	test: 0.9492625	best: 0.9492625 (509)	total: 24.8s	remaining: 15m 47s
# 510:	learn: 0.9485322	test: 0.9492800	best: 0.9492800 (510)	total: 24.9s	remaining: 15m 47s
# 511:	learn: 0.9485511	test: 0.9493225	best: 0.9493225 (511)	total: 24.9s	remaining: 15m 47s
# 512:	learn: 0.9485947	test: 0.9493450	best: 0.9493450 (512)	total: 24.9s	remaining: 15m 47s
# 513:	learn: 0.9486328	test: 0.9493625	best: 0.9493625 (513)	total: 25s	remaining: 15m 47s
# 514:	learn: 0.9486858	test: 0.9494250	best: 0.9494250 (514)	total: 25s	remaining: 15m 47s
# 515:	learn: 0.9487117	test: 0.9494450	best: 0.9494450 (515)	total: 25.1s	remaining: 15m 46s
# 516:	learn: 0.9487389	test: 0.9494475	best: 0.9494475 (516)	total: 25.1s	remaining: 15m 46s
# 517:	learn: 0.9487594	test: 0.9494825	best: 0.9494825 (517)	total: 25.2s	remaining: 15m 46s
# 518:	learn: 0.9487742	test: 0.9494975	best: 0.9494975 (518)	total: 25.2s	remaining: 15m 46s
# 519:	learn: 0.9488006	test: 0.9495125	best: 0.9495125 (519)	total: 25.3s	remaining: 15m 46s
# 520:	learn: 0.9488469	test: 0.9495550	best: 0.9495550 (520)	total: 25.3s	remaining: 15m 46s
# 521:	learn: 0.9488700	test: 0.9495850	best: 0.9495850 (521)	total: 25.4s	remaining: 15m 46s
# 522:	learn: 0.9488889	test: 0.9495975	best: 0.9495975 (522)	total: 25.4s	remaining: 15m 46s
# 523:	learn: 0.9489164	test: 0.9496200	best: 0.9496200 (523)	total: 25.5s	remaining: 15m 46s
# 524:	learn: 0.9489381	test: 0.9496475	best: 0.9496475 (524)	total: 25.5s	remaining: 15m 45s
# 525:	learn: 0.9489572	test: 0.9496750	best: 0.9496750 (525)	total: 25.5s	remaining: 15m 45s
# ...
# 19835:	learn: 0.9662297	test: 0.9613700	best: 0.9614675 (19485)	total: 16m 10s	remaining: 8.02s
# 19836:	learn: 0.9662292	test: 0.9613700	best: 0.9614675 (19485)	total: 16m 10s	remaining: 7
best: 0.9614675 (19485)	total: 16m 12s	remaining: 5.58s
# 19886:	learn: 0.9662267	test: 0.9613625	best: 0.9614675 (19485)	total: 16m 12s	remaining: 5.53s
# 19887:	learn: 0.9662250	test: 0.9613625	best: 0.9614675 (19485)	total: 16m 12s	remaining: 5.48s
# 19888:	learn: 0.9662258	test: 0.9613675	best: 0.9614675 (19485)	total: 16m 12s	remaining: 5.43s
# 19889:	learn: 0.9662261	test: 0.9613650	best: 0.9614675 (19485)	total: 16m 13s	remaining: 5.38s
# 19890:	learn: 0.9662250	test: 0.9613675	best: 0.9614675 (19485)	total: 16m 13s	remaining: 5.33s
# 19891:	learn: 0.9662250	test: 0.9613650	best: 0.9614675 (19485)	total: 16m 13s	remaining: 5.28s
# 19892:	learn: 0.9662247	test: 0.9613725	best: 0.9614675 (19485)	total: 16m 13s	remaining: 5.23s
# 19893:	learn: 0.9662258	test: 0.9613800	best: 0.9614675 (19485)	total: 16m 13s	remaining: 5.18s
# 19894:	learn: 0.9662256	test: 0.9613675	best: 0.9614675 (19485)	total: 16m 13s	remaining: 5.14s
# 19895:	learn: 0.9662272	test: 0.9613675	best: 0.9614675 (19485)	total: 16m 13s	remaining: 5.09s
# 19896:	learn: 0.9662278	test: 0.9613700	best: 0.9614675 (19485)	total: 16m 13s	remaining: 5.04s
# 19897:	learn: 0.9662297	test: 0.9613675	best: 0.9614675 (19485)	total: 16m 13s	remaining: 4.99s
# 19898:	learn: 0.9662300	test: 0.9613700	best: 0.9614675 (19485)	total: 16m 13s	remaining: 4.94s
# 19899:	learn: 0.9662317	test: 0.9613700	best: 0.9614675 (19485)	total: 16m 13s	remaining: 4.89s
# 19900:	learn: 0.9662325	test: 0.9613700	best: 0.9614675 (19485)	total: 16m 13s	remaining: 4.84s
# 19901:	learn: 0.9662322	test: 0.9613725	best: 0.9614675 (19485)	total: 16m 13s	remaining: 4.8s
# 19902:	learn: 0.9662300	test: 0.9613725	best: 0.9614675 (19485)	total: 16m 14s	remaining: 4.75s
# 19903:	learn: 0.9662306	test: 0.9613750	best: 0.9614675 (19485)	total: 16m 14s	remaining: 4.7s
# 19904:	learn: 0.9662331	test: 0.9613775	best: 0.9614675 (19485)	total: 16m 14s	remaining: 4.65s
# 19905:	learn: 0.9662331	test: 0.9613775	best: 0.9614675 (19485)	total: 16m 14s	remaining: 4.6s
# 19906:	learn: 0.9662350	test: 0.9613800	best: 0.9614675 (19485)	total: 16m 14s	remaining: 4.55s
# 19907:	learn: 0.9662356	test: 0.9613750	best: 0.9614675 (19485)	total: 16m 14s	remaining: 4.5s
# 19908:	learn: 0.9662331	test: 0.9613775	best: 0.9614675 (19485)	total: 16m 14s	remaining: 4.45s
# 19909:	learn: 0.9662339	test: 0.9613850	best: 0.9614675 (19485)	total: 16m 14s	remaining: 4.41s
# 19910:	learn: 0.9662344	test: 0.9613800	best: 0.9614675 (19485)	total: 16m 14s	remaining: 4.36s
# 19911:	learn: 0.9662353	test: 0.9613850	best: 0.9614675 (19485)	total: 16m 14s	remaining: 4.31s
# 19912:	learn: 0.9662367	test: 0.9613850	best: 0.9614675 (19485)	total: 16m 14s	remaining: 4.26s
# 19913:	learn: 0.9662372	test: 0.9613900	best: 0.9614675 (19485)	total: 16m 14s	remaining: 4.21s
# 19914:	learn: 0.9662386	test: 0.9613800	best: 0.9614675 (19485)	total: 16m 14s	remaining: 4.16s
# 19915:	learn: 0.9662375	test: 0.9613800	best: 0.9614675 (19485)	total: 16m 14s	remaining: 4.11s
# 19916:	learn: 0.9662383	test: 0.9613850	best: 0.9614675 (19485)	total: 16m 15s	remaining: 4.06s
# 19917:	learn: 0.9662369	test: 0.9613900	best: 0.9614675 (19485)	total: 16m 15s	remaining: 4.01s
# 19918:	learn: 0.9662344	test: 0.9613875	best: 0.9614675 (19485)	total: 16m 15s	remaining: 3.96s
# 19919:	learn: 0.9662356	test: 0.9613850	best: 0.9614675 (19485)	total: 16m 15s	remaining: 3.92s
# 19920:	learn: 0.9662372	test: 0.9613850	best: 0.9614675 (19485)	total: 16m 15s	remaining: 3.87s
# 19921:	learn: 0.9662375	test: 0.9613825	best: 0.9614675 (19485)	total: 16m 15s	remaining: 3.82s
# 19922:	learn: 0.9662353	test: 0.9613875	best: 0.9614675 (19485)	total: 16m 15s	remaining: 3.77s
# 19923:	learn: 0.9662331	test: 0.9613900	best: 0.9614675 (19485)	total: 16m 15s	remaining: 3.72s
# 19924:	learn: 0.9662353	test: 0.9613875	best: 0.9614675 (19485)	total: 16m 15s	remaining: 3.67s
# 19925:	learn: 0.9662353	test: 0.9613850	best: 0.9614675 (19485)	total: 16m 15s	remaining: 3.62s
# 19926:	learn: 0.9662353	test: 0.9613900	best: 0.9614675 (19485)	total: 16m 15s	remaining: 3.57s
# 19927:	learn: 0.9662367	test: 0.9613925	best: 0.9614675 (19485)	total: 16m 15s	remaining: 3.52s
# 19928:	learn: 0.9662361	test: 0.9613950	best: 0.9614675 (19485)	total: 16m 15s	remaining: 3.48s
# 19929:	learn: 0.9662364	test: 0.9613900	best: 0.9614675 (19485)	total: 16m 15s	remaining: 3
test: 0.9613875	best: 0.9614675 (19485)	total: 16m 18s	remaining: 685ms
# 19986:	learn: 0.9662569	test: 0.9613925	best: 0.9614675 (19485)	total: 16m 18s	remaining: 637ms
# 19987:	learn: 0.9662575	test: 0.9613900	best: 0.9614675 (19485)	total: 16m 18s	remaining: 588ms
# 19988:	learn: 0.9662583	test: 0.9613875	best: 0.9614675 (19485)	total: 16m 18s	remaining: 539ms
# 19989:	learn: 0.9662614	test: 0.9613925	best: 0.9614675 (19485)	total: 16m 18s	remaining: 490ms
# 19990:	learn: 0.9662617	test: 0.9613900	best: 0.9614675 (19485)	total: 16m 18s	remaining: 441ms
# 19991:	learn: 0.9662597	test: 0.9613925	best: 0.9614675 (19485)	total: 16m 18s	remaining: 392ms
# 19992:	learn: 0.9662606	test: 0.9613975	best: 0.9614675 (19485)	total: 16m 18s	remaining: 343ms
# 19993:	learn: 0.9662622	test: 0.9613925	best: 0.9614675 (19485)	total: 16m 18s	remaining: 294ms
# 19994:	learn: 0.9662617	test: 0.9613875	best: 0.9614675 (19485)	total: 16m 18s	remaining: 245ms
# 19995:	learn: 0.9662597	test: 0.9613875	best: 0.9614675 (19485)	total: 16m 19s	remaining: 196ms
# 19996:	learn: 0.9662608	test: 0.9613875	best: 0.9614675 (19485)	total: 16m 19s	remaining: 147ms
# 19997:	learn: 0.9662614	test: 0.9613900	best: 0.9614675 (19485)	total: 16m 19s	remaining: 97.9ms
# 19998:	learn: 0.9662631	test: 0.9613900	best: 0.9614675 (19485)	total: 16m 19s	remaining: 49ms
# 19999:	learn: 0.9662664	test: 0.9613925	best: 0.9614675 (19485)	total: 16m 19s	remaining: 0us
# bestTest = 0.9614675
# bestIteration = 19485
# Shrink model to first 19486 iterations.

# %%
predictions = cat.predict(test_data)
submission['Cover_Type'] = predictions
predictions[:5]
# Out:
# array([[2],
#        [2],
#        [2],
#        [2],
#        [2]])

# %%
submission.to_csv("submission.csv", index = False)

# %% [markdown]
# <div style="background-color:rgba(0, 167, 255, 0.6);border-radius:5px;display:fill">
#     <h1><center>Conclusion</center></h1>
# </div>

# %% [markdown]
# **Intel® Extension for Scikit-learn** gives you opportunities to:
# * Use your Scikit-learn code for training and inference without modification.
# * Get speed up your kernel

# %% [markdown]
# *Please upvote if you liked it.*

# %% [markdown]
# <div style="background-color:rgba(0, 167, 255, 0.6);border-radius:5px;display:fill">
#     <h1><center>Other notebooks with sklearnex usage</center></h1>
# </div>

# %% [markdown]
# ### [[predict sales] Stacking with scikit-learn-intelex](https://www.kaggle.com/alexeykolobyanin/predict-sales-stacking-with-scikit-learn-intelex)
#
# ### [[TPS-Aug] NuSVR with Intel Extension for Sklearn](https://www.kaggle.com/alexeykolobyanin/tps-aug-nusvr-with-intel-extension-for-sklearn)
#
# ### [Using scikit-learn-intelex for What's Cooking](https://www.kaggle.com/kppetrov/using-scikit-learn-intelex-for-what-s-cooking?scriptVersionId=58739642)
#
# ### [Fast KNN using  scikit-learn-intelex for MNIST](https://www.kaggle.com/kppetrov/fast-knn-using-scikit-learn-intelex-for-mnist?scriptVersionId=58738635)
#
# ### [Fast SVC using scikit-learn-intelex for MNIST](https://www.kaggle.com/kppetrov/fast-svc-using-scikit-learn-intelex-for-mnist?scriptVersionId=58739300)
#
# ### [Fast SVC using scikit-learn-intelex for NLP](https://www.kaggle.com/kppetrov/fast-svc-using-scikit-learn-intelex-for-nlp?scriptVersionId=58739339)
#
# ### [Fast AutoML with Intel Extension for Scikit-learn](https://www.kaggle.com/lordozvlad/fast-automl-with-intel-extension-for-scikit-learn)
#
# ### [[Titanic] AutoML with Intel Extension for Sklearn](https://www.kaggle.com/lordozvlad/titanic-automl-with-intel-extension-for-sklearn)
